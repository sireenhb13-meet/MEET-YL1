# %%
import csv

# %%
f = open('melanoma.csv', 'rb')
reader = csv.reader(f)
index=0
year=[]
incidence=[]
for row in reader:
    if index != 0:
        r = map(float, row)
        year.append(r[0]) 
        incidence.append(r[1])
    index +=1
f.close()

print year
# Out:
# [1936.0, 1937.0, 1938.0, 1939.0, 1940.0, 1941.0, 1942.0, 1943.0, 1944.0, 1945.0, 1946.0, 1947.0, 1948.0, 1949.0, 1950.0, 1951.0, 1952.0, 1953.0, 1954.0, 1955.0, 1956.0, 1957.0, 1958.0, 1959.0, 1960.0, 1961.0, 1962.0, 1963.0, 1964.0, 1965.0, 1966.0, 1967.0, 1968.0, 1969.0, 1970.0, 1971.0, 1972.0]

# %%
from pylab import *

# %%
scatter(year, incidence)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_title('Oyster year and incidence')
ax.set_xlabel('Oyster year (g)')
ax.set_ylabel('Oyster incidence ')
ax.scatter(year, incidence)
fig.savefig("oyster_with_titles.png")
